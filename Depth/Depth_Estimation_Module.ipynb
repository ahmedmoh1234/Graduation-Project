# %%
# import shutil

# directory_path = "/content/repo_content"

# shutil.rmtree(directory_path)

# %%
# !source deactivate
# !conda env remove --name midas-py310

# %%
import subprocess

# Define the GitHub repository URL
repo_url = "https://github.com/isl-org/MiDaS"

# Specify the destination directory to clone the repository
destination_dir = "/content/repo_content"

# Clone the repository using git
subprocess.run(["git", "clone", repo_url, destination_dir])

print("Repository content downloaded and stored in:", destination_dir)
# Out:
# Repository content downloaded and stored in: /content/repo_content

# %%
import sys

directory_path = "./repo_content"

sys.path.append(directory_path)

# %%
# !chmod +x ./repo_content/run.py

# %%
import urllib.request
import os

# Define the URL of the model file
url = 'https://github.com/isl-org/MiDaS/releases/download/v3_1/dpt_beit_large_512.pt'

# Specify the destination directory to save the model file
destination_dir = './weights'

# Create the destination directory if it doesn't exist
os.makedirs(destination_dir, exist_ok=True)

# Extract the filename from the URL
filename = os.path.basename(url)

# Build the complete path for saving the model file
save_path = os.path.join(destination_dir, filename)

# Download the model file
urllib.request.urlretrieve(url, save_path)

print("Model file downloaded and saved to:", save_path)
# Out:
# Model file downloaded and saved to: ./weights/dpt_beit_large_512.pt

# %%
import sys
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
# !wget -q https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -O miniconda.sh && \
bash miniconda.sh -bfp /usr/local
# Out:
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
#
# ...
#
#
# ...
#
# done
# done
# installation finished.

# %%
# %%bash
# conda install --channel defaults conda python=3.10 --yes
# conda update --channel defaults --all --yes
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2023.5.7           |  py310h06a4308_0         152 KB
#     ------------------------------------------------------------
#                                            Total:         152 KB
#
# The following packages will be UPDATED:
#
#   certifi                         2022.12.7-py310h06a4308_0 --> 2023.5.7-py310h06a4308_0
#
#
#
# ...
# certifi-2023.5.7     | 152 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#
# ...

# %%
sys.path.append("/usr/local/lib/python3.10/site-packages")

# %%
# !conda env create -f ./repo_content/environment.yaml
# Out:
# done
# done
#
# ...
# cuda-cupti-11.7.101  | 22.9 MB   | :   0% 0/1 [00:00<?, ?it/s]
# pytorch-cuda-11.7    | 3 KB      | :   0% 0/1 [00:00<?, ?it/s]
#
# numpy-1.23.4         | 10 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
# lcms2-2.12           | 312 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libcublas-11.10.3.66 | 286.1 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# zstd-1.5.5           | 647 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# libcurand-10.3.2.106 | 51.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libwebp-1.2.4        | 86 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# pip-22.3.1           | 2.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# libwebp-base-1.2.4   | 376 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# nettle-3.7.3         | 809 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# libidn2-2.3.4        | 146 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 262 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# ...

# %%
# !source activate midas-py310

# %%
import subprocess

command = [
    'conda', 'run', '--no-capture-output', '-n', 'midas-py310', 'python', '/content/repo_content/run.py',
    '--model_type', 'dpt_beit_large_512', '--input_path', './images', '--output_path', './output'
]

process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
stdout, stderr = process.communicate()

if process.returncode == 0:
    print("Command executed successfully.")
else:
    print(f"Command execution failed with error:\n{stderr.decode('utf-8')}")
# Out:
# Command executed successfully.

# %%
import urllib.request
import os

yolo_url = "https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8s-seg.pt"
# yolo_url = "https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8m.pt"


# Specify the destination directory to save the model file
destination_dir = './weights'

# Create the destination directory if it doesn't exist
os.makedirs(destination_dir, exist_ok=True)

# Extract the filename from the URL
filename = os.path.basename(yolo_url)

# Build the complete path for saving the model file
save_path = os.path.join(destination_dir, filename)

# Download the model file
urllib.request.urlretrieve(yolo_url, save_path)

print("Model file downloaded and saved to:", save_path)
# Out:
# Model file downloaded and saved to: ./weights/yolov8s-seg.pt

# %%
import subprocess

# Define the GitHub repository URL
repo_url = "https://github.com/ultralytics/ultralytics"

# Specify the destination directory to clone the repository

# Clone the repository using git
subprocess.run(["git", "clone", repo_url])

print("Repository content downloaded")
# Out:
# Repository content downloaded

# %%
import sys

directory_path = "./ultralytics"

sys.path.append(directory_path)

# %%
classes = ["person","bicycle","car","motorbike","aeroplane","bus","train","truck","boat","traffic light","fire hydrant","stop sign","parking meter","bench","bird","cat","dog","horse","sheep","cow","elephant","bear","zebra","giraffe","backpack","umbrella","handbag","tie","suitcase","frisbee","skis","snowboard","sports ball","kite","baseball bat","baseball glove","skateboard","surfboard","tennis racket","bottle","wine glass","cup","fork","knife","spoon","bowl","banana","apple","sandwich","orange","broccoli","carrot","hot dog","pizza","donut","cake","chair","sofa","potted plant","bed","dining table","toilet","TV monitor","laptop","mouse","remote","keyboard","cell phone","microwave","oven","toaster","sink","refrigerator","book","clock","vase","scissors","teddy bear","hair dryer","toothbrush"]

# %%
objects_real_width = {
"person":180,
"bicycle":220,
"car":500,
"motorbike":220,
"aeroplane":800,
"bus":300,
"train":2000,
"truck":400,
"boat":800,
"traffic light":150,
"fire hydrant":80,
"stop sign":120,
"parking meter":80,
"bench":180,
"bird":50,
"cat":40,
"dog":50,
"horse":200,
"sheep":120,
"cow":200,
"elephant":600,
"bear":250,
"zebra":300,
"giraffe":600,
"backpack":60,
"umbrella":150,
"handbag":50,
"tie":40,
"suitcase":200,
"frisbee":30,
"skis":200,
"snowboard":200,
"sports ball":30,
"kite":80,
"baseball bat":100,
"baseball glove":60,
"skateboard":120,
"surfboard":200,
"tennis racket":100,
"bottle":30,
"wine glass":30,
"cup":11,
"fork":30,
"knife":30,
"spoon":30,
"bowl":30,
"banana":20,
"apple":10,
"sandwich":20,
"orange":10,
"broccoli":30,
"carrot":20,
"hot dog":20,
"pizza":30,
"donut":20,
"cake":30,
"chair":100,
"sofa":200,
"potted plant":120,
"bed":200,
"dining table":300,
"toilet":120,
"TV monitor":150,
"laptop":40,
"mouse":10,
"remote":10,
"keyboard":40,
"cell phone":10,
"microwave":60,
"oven":80,
"toaster":40,
"sink":80,
"refrigerator":200,
"book":30,
"clock":30,
"vase":80,
"scissors":30,
"teddy bear":80,
"hair dryer":30,
"toothbrush":10
}

# %%
import pickle

with open("classes.pkl", "wb") as f:
    pickle.dump(classes, f)
    
with open("objects_real_width.pkl", "wb") as f:
    pickle.dump(objects_real_width, f)

# %%
from ultralytics import YOLO
import numpy as np


class YOLOSegmentation:
    def __init__(self, model_path):
        self.model = YOLO(model_path)


    def detect(self, img):
        # Get image shape
        height, width, channels = img.shape
        results = self.model.predict(conf=0.5, source=img.copy(), save=False, save_txt=False)
        result = results[0]
        segmentation_countours_indx = []
        for seg in result.masks.xyn:
            # contours
            seg[:, 0] *= width
            seg[:, 1] *= height
            segment = np.array(seg, dtype=np.int32)
            segmentation_countours_indx.append(segment)

        bboxes = np.array(result.boxes.xyxy.cpu(), dtype="int")
        # Get the class ids
        class_ids = np.array(result.boxes.cls.cpu(), dtype="int")

        # Get scores
        scores = np.array(result.boxes.conf.cpu(), dtype="float").round(2)
        
        return bboxes, class_ids, segmentation_countours_indx, scores

# %%
# object_width = 11                     # in real life in cm
# distance_to_object = 100                # in real life in cm
# image_width = 103                      # in px in the image
# focal_length = (object_width * distance_to_object) / image_width
# print(f"focal length: {focal_length}")
focal_length = 167.5

# %%
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import numpy as np

# Instantiate YOLOSegmentation object
ys = YOLOSegmentation("./weights/yolov8s-seg.pt")

# Load and preprocess image
original_image = Image.open("./images/Nos.jpg")
original_image = np.array(original_image)
plt.imshow(original_image)
plt.show()

image = Image.open("/content/output/Nos-dpt_beit_large_512.png")
image = np.array(image)
gray_heat_map = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.imshow(gray_heat_map)
plt.show()
print(f"Heat map shape: {image.shape}")
print(f"Gray Heat map shape: {gray_heat_map.shape}")
# Call the detect function
bboxes, class_ids, seg, scores = ys.detect(original_image)
arr_obj_px = []

# Iterate over each segment in seg
for i in range(len(seg)):
    # Create a blank mask image of the same size as the original image
    mask = np.zeros_like(image[:, :,0])
    class_id = class_ids[i]
    detected_object = classes[class_id]

    # Convert the segment to a NumPy array and round the coordinates to integers
    segment = np.array(seg[i], dtype=np.int32)

    # Get the bounding rectangle of the segment
    x, y, w, h = cv2.boundingRect(segment)
    
    # Print the width and height of the bounding rectangle
    print(f"Object: {detected_object}")
    print("Width:", w)
    print("Height:", h)
    
    # Draw the contour on the mask image
    cv2.drawContours(mask, [segment], -1, (255), thickness=cv2.FILLED)
    segmented_image = cv2.bitwise_and(image,image,mask=mask)

    gray_segmented_image = cv2.cvtColor(segmented_image,cv2.COLOR_BGR2GRAY) / 255.0

    depth_value = np.max(gray_segmented_image) #depth_value is the depth value obtained from the depth map

    object_pixel_width = max(w,h) # object_pixel_width is the width of the object's bounding box in pixels.

    object_width = objects_real_width[detected_object]

    distance_to_object = (object_width * focal_length) / (object_pixel_width * depth_value)
    print(f"distance_to_object = ({object_width} * {focal_length}) / ({object_pixel_width} * {depth_value})")

    print(f"Detected Object:{detected_object}")
    print(f"Distance to object is: {distance_to_object} cm")

    plt.imshow(segmented_image)
    plt.show()

arr_obj_px = np.array(arr_obj_px)
# Out:
# Heat map shape: (960, 1280, 3)
# Gray Heat map shape: (960, 1280)
# 0: 480x640 1 cup, 2 chairs, 1 dining table, 24.3ms
# Speed: 2.7ms preprocess, 24.3ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
# Object: cup
# Width: 215
# Height: 199
# distance_to_object = (11 * 167.5) / (215 * 0.2823529411764706)
# Detected Object:cup
# Distance to object is: 30.351259689922482 cm
# Object: dining table
# Width: 1271
# Height: 579
# distance_to_object = (300 * 167.5) / (1271 * 0.8745098039215686)
# Detected Object:dining table
# Distance to object is: 45.20909703527818 cm
# Object: chair
# Width: 87
# Height: 221
# distance_to_object = (100 * 167.5) / (221 * 0.1450980392156863)
# Detected Object:chair
# Distance to object is: 522.3492723492723 cm
# Object: chair
# Width: 229
# Height: 327
# distance_to_object = (100 * 167.5) / (327 * 0.1803921568627451)
# Detected Object:chair
# Distance to object is: 283.95492620662145 cm
